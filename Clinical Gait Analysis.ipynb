# %%
import pandas as pd
from sklearn.model_selection import train_test_split

data = pd.read_csv('C:\\Users\\turan\\Desktop\\1\\Dataset(1).csv', sep=';')  #read data from csv
data = pd.DataFrame(data)

data["speedmin"] = data["speedmin"].str.replace(",", ".")     #change ',' to '.'
data["speedavg"] = data["speedavg"].str.replace(",", ".")
data["speedmax"] = data["speedmax"].str.replace(",", ".")
data["steplengthmin"] = data["steplengthmin"].str.replace(",", ".")
data["steplengthmax"] = data["steplengthmax"].str.replace(",", ".")
data["stridelengthmin"] = data["stridelengthmin"].str.replace(",", ".")
data["stridelengthmax"] = data["stridelengthmax"].str.replace(",", ".")
data["steptimemin"] = data["steptimemin"].str.replace(",", ".")
data["steptimeavg"] = data["steptimeavg"].str.replace(",", ".")
data["steptimemax"] = data["steptimemax"].str.replace(",", ".")
data["stridetimemin"] = data["stridetimemin"].str.replace(",", ".")
data["stridetimeavg"] = data["stridetimeavg"].str.replace(",", ".")
data["stridetimemax"] = data["stridetimemax"].str.replace(",", ".")
data["onemeterdistance"] = data["onemeterdistance"].str.replace(",", ".")

data["speedmin"] = data.speedmin.astype(float)               #change data type object to float
data["speedavg"] = data.speedavg.astype(float)
data["speedmax"] = data.speedmax.astype(float)
data["steplengthmin"] = data.steplengthmin.astype(float)
data["steplengthmax"] = data.steplengthmax.astype(float)
data["stridelengthmin"] = data.stridelengthmin.astype(float)
data["stridelengthmax"] = data.stridelengthmax.astype(float)
data["steptimemin"] = data.steptimemin.astype(float)
data["steptimeavg"] = data.steptimeavg.astype(float)
data["steptimemax"] = data.steptimemax.astype(float)
data["stridetimemin"] = data.stridetimemin.astype(float)
data["stridetimeavg"] = data.stridetimeavg.astype(float)
data["stridetimemax"] = data.stridetimemax.astype(float)
data["onemeterdistance"] = data.onemeterdistance.astype(float)

X = data.iloc[:, 0:54]
y = data.iloc[:, 54:55]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

randomforest = RandomForestClassifier(random_state=42,n_estimators=50)

randomforest.fit(X_train, y_train.values.ravel())
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=50,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
y_pred = randomforest.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
print("Accuracy: ",accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  1.0

# %%
from sklearn.model_selection import cross_validate

cv = cross_validate(randomforest, X_train, y_train.values.ravel(), cv=10)
print(cv['test_score'])
print(cv['test_score'].mean())
# Out:
# [1.         0.8        1.         0.9        0.9        1.
#  0.88888889 1.         1.         0.88888889]
# 0.9377777777777778

# %%
randomforest.estimators_
# Out:
# [DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                         max_depth=None, max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=1608637542, splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                         max_depth=None, max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=1273642419, splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
# ...

# %%
len(randomforest.estimators_)
# Out:
# 50

# %%
from sklearn import tree
plt.figure(figsize=(20,15))
tree.plot_tree(randomforest.estimators_[1],filled=True)
# Out:
# [Text(524.52, 757.1571428571428, 'X[6] <= 1.195\ngini = 0.826\nsamples = 62\nvalue = [17, 19, 21, 17, 10, 15]'),
#  Text(435.24, 640.6714285714286, 'X[8] <= 28.5\ngini = 0.789\nsamples = 51\nvalue = [0, 19, 21, 17, 10, 15]'),
#  Text(178.56, 524.1857142857143, 'X[17] <= 0.58\ngini = 0.355\nsamples = 15\nvalue = [0, 0, 20, 0, 0, 6]'),
#  Text(89.28, 407.7, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 20, 0, 0, 0]'),
#  Text(267.84000000000003, 407.7, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 0, 6]'),
#  Text(691.92, 524.1857142857143, 'X[21] <= 46.0\ngini = 0.735\nsamples = 36\nvalue = [0, 19, 1, 17, 10, 9]'),
#  Text(446.4, 407.7, 'X[37] <= 162.5\ngini = 0.636\nsamples = 24\nvalue = [0, 19, 1, 0, 10, 8]'),
#  Text(223.2, 291.21428571428567, 'X[35] <= 105.5\ngini = 0.198\nsamples = 7\nvalue = [0, 0, 1, 0, 0, 8]'),
#  Text(133.92000000000002, 174.7285714285714, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 0, 8]'),
# ...

# %%
plt.figure(figsize=(20,15))
tree.plot_tree(randomforest.estimators_[2],filled=True)
# Out:
# [Text(540.5625, 770.1, 'X[29] <= 177.0\ngini = 0.823\nsamples = 63\nvalue = [13, 18, 14, 12, 24, 18]'),
#  Text(348.75, 679.5, 'X[45] <= 55.5\ngini = 0.1\nsamples = 13\nvalue = [0, 0, 1, 0, 0, 18]'),
#  Text(279.0, 588.9, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(418.5, 588.9, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 0, 0, 0, 18]'),
#  Text(732.375, 679.5, 'X[16] <= 1.835\ngini = 0.784\nsamples = 50\nvalue = [13, 18, 13, 12, 24, 0]'),
#  Text(558.0, 588.9, 'X[52] <= 153.5\ngini = 0.661\nsamples = 33\nvalue = [13, 1, 13, 1, 24, 0]'),
#  Text(418.5, 498.3, 'X[17] <= 0.83\ngini = 0.483\nsamples = 22\nvalue = [13, 1, 0, 0, 24, 0]'),
#  Text(348.75, 407.7, 'X[1] <= 3.5\ngini = 0.536\nsamples = 17\nvalue = [13, 1, 0, 0, 12, 0]'),
#  Text(279.0, 317.1, 'X[7] <= 29.33\ngini = 0.32\nsamples = 13\nvalue = [13, 1, 0, 0, 2, 0]'),
#  Text(209.25, 226.5, 'X[42] <= 75.0\ngini = 0.625\nsamples = 4\nvalue = [1, 1, 0, 0, 2, 0]'),
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier, export_graphviz
for f in X:
    plt.figure(figsize=(20, 18), dpi=100)
    ax = sns.countplot(x=f, data=data, hue = 'Disease', palette="Set1")
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
